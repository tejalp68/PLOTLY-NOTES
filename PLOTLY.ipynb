# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\tejal dadaji pagar\appdata\local\programs\python\python312\lib\site-packages (6.5.2)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\tejal dadaji pagar\appdata\local\programs\python\python312\lib\site-packages (from plotly) (2.15.0)
# Requirement already satisfied: packaging in c:\users\tejal dadaji pagar\appdata\local\programs\python\python312\lib\site-packages (from plotly) (25.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\tejal dadaji pagar\appdata\local\programs\python\python312\lib\site-packages (25.3)
# Collecting pip
#   Downloading pip-26.0.1-py3-none-any.whl.metadata (4.7 kB)
# Downloading pip-26.0.1-py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----------------------------------- ---- 1.6/1.8 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 6.1 MB/s  0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 25.3
#     Uninstalling pip-25.3:
#       Successfully uninstalled pip-25.3
# Successfully installed pip-26.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotly.express as px
import plotly.graph_objects as go

# %%
## built in data set
df = px.data.iris()
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      species_id
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ..          ...
# 145           3
# 146           3
# 147           3
# 148           3
# 149           3
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Scatter Plot

# %%
fig = px.scatter(df, x="sepal_width", y="sepal_length",
                 color="species")
fig.show()

# %%
fig = px.scatter(df, x="sepal_width", y="sepal_length",
                 size="petal_length",color="species")
fig.show()

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(
    x=df["sepal_width"],
    y=df["sepal_length"],
    mode="markers"
))

fig.show()

# %%
fig = px.scatter_3d(df,
                    x="sepal_width",
                    y="sepal_length",
                    z="petal_length",
                    color="species")
fig.show()

# %% [markdown]
# ### Line plot

# %%
fig = px.line(df, x="sepal_width", y="sepal_length")
fig.show()

# %% [markdown]
# ## subplot

# %%
from plotly.subplots import make_subplots

fig = make_subplots(rows=1, cols=2)

fig.add_trace(go.Scatter(x=df["sepal_width"],
                         y=df["sepal_length"]),
              row=1, col=1)

fig.add_trace(go.Bar(x=df["species"],
                     y=df["sepal_length"]),
              row=1, col=2)

fig.show()

# %% [markdown]
# ## ANIMATED GRAPH

# %%
df_gap = px.data.gapminder()

fig = px.scatter(df_gap,
                 x="gdpPercap",
                 y="lifeExp",
                 animation_frame="year",
                 animation_group="country",
                 size="pop",
                 color="continent",
                 hover_name="country",
                 log_x=True)

fig.show()

# %% [markdown]
# ## BAR GRAPH

# %%
fig = px.bar(df, x="species", y="species_id")
fig.show()

# %%
fig = px.bar(df, x="species", y="species_id",barmode ='group')
fig.show()

# %% [markdown]
# #### Three graph on single graph

# %%
x1,y1=[1,2,3,4,5,6] ,[5,2,3,6,7,4]
x2,y2=[1,2,3,4,5,6] ,[2,5,9,7,8,5]
x3,y3=[1,2,3,4,5,6] ,[4,8,6,5,1,2]

# %%
fig =go.Figure()
fig.add_trace(go.Scatter(x=x1,y=y1))
fig.add_trace(go.Scatter(x=x2,y=y2))
fig.add_trace(go.Scatter(x=x2,y=y3))

# %%
fig =go.Figure()
fig.add_trace(go.Scatter(x=x1,y=y1,name ="line1",mode="lines"))
fig.add_trace(go.Scatter(x=x2,y=y2,name ='Line2',mode ='markers'))
fig.add_trace(go.Scatter(x=x2,y=y3,name ='Line3',mode ='lines +markers'))

# %%
color=['A','B','C','D','E','F']
fig=px.scatter(x=x1,y=y1,size=y1,color=color)
fig.show()

# %% [markdown]
# ## BUBBLE CHART

# %%
x=[12,3,4,8]
y=[4,6,8,10]

# %%
fig = go.Figure(go.Scatter(x=x,y=y,mode='markers'))
fig.show()

# %%
fig = go.Figure(go.Scatter(x=x,y=y,mode='markers',marker_size=[90,60,70,80]))
fig.show()
